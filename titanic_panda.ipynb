# %%
import pandas as pd
import numpy as np

# %%
titanic_data=pd.read_csv("titanic.csv")

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(titanic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data[["Survived"]][0:5]
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
titanic_data[["Survived","Age"]][0:5]
# Out:
#    Survived   Age
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0
# 4         0  35.0

# %%
titanic_data[["Survived"]].value_counts()
# Out:
# Survived
# 0           549
# 1           342
# Name: count, dtype: int64

# %%
titanic_data[["Survived"]].value_counts(normalize=True)*100
# Out:
# Survived
# 0           61.616162
# 1           38.383838
# Name: proportion, dtype: float64

# %%
pd.crosstab(titanic_data.Sex,titanic_data.Survived)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(titanic_data.Sex,titanic_data.Survived,normalize=True)
# Out:
# Survived         0         1
# Sex
# female    0.090909  0.261504
# male      0.525253  0.122334

# %%
pd.crosstab(titanic_data.Sex,titanic_data.Survived, normalize="columns")
# Out:
# Survived         0         1
# Sex
# female    0.147541  0.681287
# male      0.852459  0.318713

# %%
male_below_5=titanic_data[(titanic_data.Age<=5) & (titanic_data.Survived>0)]

# %%
male_below_5.shape
# Out:
# (31, 12)

# %%
titanic_data[titanic_data.Age<=5]["Survived"].value_counts()
titanic_data[titanic_data.Age<=5]["Survived"].value_counts(normalize=True)
# Out:
# Survived
# 1    0.704545
# 0    0.295455
# Name: proportion, dtype: float64

# %%
titanic_data[titanic_data.Age<=5][["Survived","Age"]]
# Out:
#      Survived   Age
# 7           0  2.00
# 10          1  4.00
# 16          0  2.00
# 43          1  3.00
# 58          1  5.00
# 63          0  4.00
# 78          1  0.83
# 119         0  2.00
# 164         0  1.00
# 171         0  4.00
# 172         1  1.00
# 183         1  1.00
# 184         1  4.00
# 193         1  3.00
# 205         0  2.00
# 233         1  5.00
# 261         1  3.00
# 297         0  2.00
# 305         1  0.92
# 340         1  2.00
# 348         1  3.00
# 374         0  3.00
# 381         1  1.00
# 386         0  1.00
# 407         1  3.00
# 445         1  4.00
# 448         1  5.00
# 469         1  0.75
# 479         1  2.00
# 530         1  2.00
# 618         1  4.00
# 642         0  2.00
# 644         1  0.75
# 691         1  4.00
# 750         1  4.00
# 755         1  0.67
# 777         1  5.00
# 788         1  1.00
# 803         1  0.42
# 824         0  2.00
# 827         1  1.00
# 831         1  0.83
# 850         0  4.00
# 869         1  4.00

# %%
titanic_data[titanic_data.Name.str.contains("Allen")]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 4              5         0       3       Allen, Mr. William Henry    male
# 730          731         1       1  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 4    35.0      0      0  373450    8.0500   NaN        S
# 730  29.0      0      0   24160  211.3375    B5        S

# %%
titanic_data.groupby("Pclass")["Age"].mean().reset_index()
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
titanic_data.groupby(["Pclass","Sex"])["Age"].mean().reset_index()
# Out:
#    Pclass     Sex        Age
# 0       1  female  34.611765
# 1       1    male  41.281386
# 2       2  female  28.722973
# 3       2    male  30.740707
# 4       3  female  21.750000
# 5       3    male  26.507589

# %%
titanic_data.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 380          381         1       1                   Bidois, Miss. Rosalie
# 243          244         0       3           Maenpaa, Mr. Matti Alexanteri
# 346          347         1       2               Smith, Miss. Marion Elsie
# 504          505         1       1                   Maioni, Miss. Roberta
# 166          167         1       1  Chibnall, Mrs. (Edith Martha Bowerman)
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 380  female  42.0      0      0           PC 17757  227.525   NaN        C
# 243    male  22.0      0      0  STON/O 2. 3101275    7.125   NaN        S
# 346  female  40.0      0      0              31418   13.000   NaN        S
# 504  female  16.0      0      0             110152   86.500   B79        S
# 166  female   NaN      0      1             113505   55.000   E33        S

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
titanic_data.iloc[[3,4],[5,6,1]]
# Out:
#     Age  SibSp  Survived
# 3  35.0      1         1
# 4  35.0      0         0

# %%
titanic_data.iloc[:,[1,3]]
# Out:
#      Survived                                               Name
# 0           0                            Braund, Mr. Owen Harris
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1                             Heikkinen, Miss. Laina
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0                           Allen, Mr. William Henry
# ..        ...                                                ...
# 886         0                              Montvila, Rev. Juozas
# 887         1                       Graham, Miss. Margaret Edith
# 888         0           Johnston, Miss. Catherine Helen "Carrie"
# 889         1                              Behr, Mr. Karl Howell
# 890         0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
titanic_2=pd.read_csv("titanic.csv",index_col="Name")

# %%
titanic_2
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic_2.loc[:,['Age','Sex',]]
# Out:
#                                                      Age     Sex
# Name
# Braund, Mr. Owen Harris                             22.0    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0  female
# Heikkinen, Miss. Laina                              26.0  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0  female
# Allen, Mr. William Henry                            35.0    male
# ...                                                  ...     ...
# Montvila, Rev. Juozas                               27.0    male
# Graham, Miss. Margaret Edith                        19.0  female
# Johnston, Miss. Catherine Helen "Carrie"             NaN  female
# Behr, Mr. Karl Howell                               26.0    male
# Dooley, Mr. Patrick                                 32.0    male
#
# [891 rows x 2 columns]

# %%
titanic_data.query('Survived==1 and Sex=="male" and Fare>1')
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...
